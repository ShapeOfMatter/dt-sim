# %%
import csv
from dataclasses import (dataclass, field, fields)
import matplotlib.pyplot as plt
import numpy as np
import re
import statistics

# %%
CSV_FILE_PATH = "../gitignore/cube_search/small_2023_Sep_13_15_05_11_.csv"

# %%
@dataclass(frozen=True)
class TestPower:
    p_column: str = field(compare=False)
    t_column: str = field(compare=False, metadata={"dontparse": True})
    iterations: int
    trainingN: int
    testingN: int

# %%
headerparser = re.compile(r"(?P<p_column>test_(?P<iterations>\d+)_(?P<trainingN>\d+)_(?P<testingN>\d+)_p)")

# %%
def score (s : str) -> int:
    p = float(s)
    if 0.05 < p:
        return 2
    elif 0.01 < p:
        return 1
    else:
        return 0
    
def estimate_time(data, tp: TestPower, std_devs: int = 0):
    usedata = [float(d[tp][1]) for d in data]
    mean = statistics.mean(usedata)
    std_dev = statistics.stdev(usedata, xbar=mean)
    return mean # + (std_devs * std_dev)

# %%
with open(CSV_FILE_PATH, 'r', newline="") as f:
    dr = csv.DictReader(f)
    test_powers = tuple(TestPower(t_column = match.group("p_column")[:-1] + "time",
                                  **{field.name: field.type(match.group(field.name))
                                     for field in fields(TestPower)
                                     if field.metadata.get("dontparse") is None})
                        for match in map(headerparser.fullmatch, dr.fieldnames)
                        if match is not None
                       )
    data = {row["filename"] : {tp : (score(row[tp.p_column]), row[tp.t_column])
                               for tp in test_powers}
            for row in dr}

p_scores = {tp : sum(d[tp][0] for d in data.values())
            for tp in test_powers}
high_times = {tp : estimate_time(data.values(), tp, std_devs=2)
              for tp in test_powers}
test_powers
# Out:
# (TestPower(p_column='test_20_64_64_p', t_column='test_20_64_64_time', iterations=20, trainingN=64, testingN=64),
#  TestPower(p_column='test_20_64_256_p', t_column='test_20_64_256_time', iterations=20, trainingN=64, testingN=256),
#  TestPower(p_column='test_20_64_448_p', t_column='test_20_64_448_time', iterations=20, trainingN=64, testingN=448),
#  TestPower(p_column='test_20_64_640_p', t_column='test_20_64_640_time', iterations=20, trainingN=64, testingN=640),
#  TestPower(p_column='test_20_64_832_p', t_column='test_20_64_832_time', iterations=20, trainingN=64, testingN=832),
#  TestPower(p_column='test_20_256_64_p', t_column='test_20_256_64_time', iterations=20, trainingN=256, testingN=64),
#  TestPower(p_column='test_20_256_256_p', t_column='test_20_256_256_time', iterations=20, trainingN=256, testingN=256),
#  TestPower(p_column='test_20_256_448_p', t_column='test_20_256_448_time', iterations=20, trainingN=256, testingN=448),
#  TestPower(p_column='test_20_256_640_p', t_column='test_20_256_640_time', iterations=20, trainingN=256, testingN=640),
#  TestPower(p_column='test_20_256_832_p', t_column='test_20_256_832_time', iterations=20, trainingN=256, testingN=832),
#  TestPower(p_column='test_20_448_64_p', t_column='test_20_448_64_time', iterations=20, trainingN=448, testingN=64),
#  TestPower(p_column='test_20_448_256_p', t_column='test_20_448_256_time', iterations=20, trainingN=448, testingN=256),
#  TestPower(p_column='test_20_448_448_p', t_column='test_20_448_448_time', iterations=20, trainingN=448, testingN=448),
#  TestPower(p_column='test_20_448_640_p', t_column='test_20_448_640_time', iterations=20, trainingN=448, testingN=640),
#  TestPower(p_column='test_20_448_832_p', t_column='test_20_448_832_time', iterations=20, trainingN=448, testingN=832),
#  TestPower(p_column='test_20_640_64_p', t_column='test_20_640_64_time', iterations=20, trainingN=640, testingN=64),
#  TestPower(p_column='test_20_640_256_p', t_column='test_20_640_256_time', iterations=20, trainingN=640, testingN=256),
#  TestPower(p_column='test_20_640_448_p', t_column='test_20_640_448_time', iterations=20, trainingN=640, testingN=448),
#  TestPower(p_column='test_20_640_640_p', t_column='test_20_640_640_time', iterations=20, trainingN=640, testingN=640),
#  TestPower(p_column='test_20_640_832_p', t_column='test_20_640_832_time', iterations=20, trainingN=640, testingN=832),
#  TestPower(p_column='test_20_832_64_p', t_column='test_20_832_64_time', iterations=20, trainingN=832, testingN=64),
#  TestPower(p_column='test_20_832_256_p', t_column='test_20_832_256_time', iterations=20, trainingN=832, testingN=256),
#  TestPower(p_column='test_20_832_448_p', t_column='test_20_832_448_time', iterations=20, trainingN=832, testingN=448),
#  TestPower(p_column='test_20_832_640_p', t_column='test_20_832_640_time', iterations=20, trainingN=832, testingN=640),
#  TestPower(p_column='test_20_832_832_p', t_column='test_20_832_832_time', iterations=20, trainingN=832, testingN=832),
#  TestPower(p_column='test_40_64_64_p', t_column='test_40_64_64_time', iterations=40, trainingN=64, testingN=64),
#  TestPower(p_column='test_40_64_256_p', t_column='test_40_64_256_time', iterations=40, trainingN=64, testingN=256),
#  TestPower(p_column='test_40_64_448_p', t_column='test_40_64_448_time', iterations=40, trainingN=64, testingN=448),
#  TestPower(p_column='test_40_64_640_p', t_column='test_40_64_640_time', iterations=40, trainingN=64, testingN=640),
#  TestPower(p_column='test_40_64_832_p', t_column='test_40_64_832_time', iterations=40, trainingN=64, testingN=832),
#  TestPower(p_column='test_40_256_64_p', t_column='test_40_256_64_time', iterations=40, trainingN=256, testingN=64),
#  TestPower(p_column='test_40_256_256_p', t_column='test_40_256_256_time', iterations=40, trainingN=256, testingN=256),
#  TestPower(p_column='test_40_256_448_p', t_column='test_40_256_448_time', iterations=40, trainingN=256, testingN=448),
#  TestPower(p_column='test_40_256_640_p', t_column='test_40_256_640_time', iterations=40, trainingN=256, testingN=640),
#  TestPower(p_column='test_40_256_832_p', t_column='test_40_256_832_time', iterations=40, trainingN=256, testingN=832),
#  TestPower(p_column='test_40_448_64_p', t_column='test_40_448_64_time', iterations=40, trainingN=448, testingN=64),
#  TestPower(p_column='test_40_448_256_p', t_column='test_40_448_256_time', iterations=40, trainingN=448, testingN=256),
#  TestPower(p_column='test_40_448_448_p', t_column='test_40_448_448_time', iterations=40, trainingN=448, testingN=448),
#  TestPower(p_column='test_40_448_640_p', t_column='test_40_448_640_time', iterations=40, trainingN=448, testingN=640),
#  TestPower(p_column='test_40_448_832_p', t_column='test_40_448_832_time', iterations=40, trainingN=448, testingN=832),
#  TestPower(p_column='test_40_640_64_p', t_column='test_40_640_64_time', iterations=40, trainingN=640, testingN=64),
#  TestPower(p_column='test_40_640_256_p', t_column='test_40_640_256_time', iterations=40, trainingN=640, testingN=256),
#  TestPower(p_column='test_40_640_448_p', t_column='test_40_640_448_time', iterations=40, trainingN=640, testingN=448),
#  TestPower(p_column='test_40_640_640_p', t_column='test_40_640_640_time', iterations=40, trainingN=640, testingN=640),
#  TestPower(p_column='test_40_640_832_p', t_column='test_40_640_832_time', iterations=40, trainingN=640, testingN=832),
#  TestPower(p_column='test_40_832_64_p', t_column='test_40_832_64_time', iterations=40, trainingN=832, testingN=64),
#  TestPower(p_column='test_40_832_256_p', t_column='test_40_832_256_time', iterations=40, trainingN=832, testingN=256),
#  TestPower(p_column='test_40_832_448_p', t_column='test_40_832_448_time', iterations=40, trainingN=832, testingN=448),
#  TestPower(p_column='test_40_832_640_p', t_column='test_40_832_640_time', iterations=40, trainingN=832, testingN=640),
#  TestPower(p_column='test_40_832_832_p', t_column='test_40_832_832_time', iterations=40, trainingN=832, testingN=832),
#  TestPower(p_column='test_60_64_64_p', t_column='test_60_64_64_time', iterations=60, trainingN=64, testingN=64),
#  TestPower(p_column='test_60_64_256_p', t_column='test_60_64_256_time', iterations=60, trainingN=64, testingN=256),
#  TestPower(p_column='test_60_64_448_p', t_column='test_60_64_448_time', iterations=60, trainingN=64, testingN=448),
#  TestPower(p_column='test_60_64_640_p', t_column='test_60_64_640_time', iterations=60, trainingN=64, testingN=640),
#  TestPower(p_column='test_60_64_832_p', t_column='test_60_64_832_time', iterations=60, trainingN=64, testingN=832),
#  TestPower(p_column='test_60_256_64_p', t_column='test_60_256_64_time', iterations=60, trainingN=256, testingN=64),
#  TestPower(p_column='test_60_256_256_p', t_column='test_60_256_256_time', iterations=60, trainingN=256, testingN=256),
#  TestPower(p_column='test_60_256_448_p', t_column='test_60_256_448_time', iterations=60, trainingN=256, testingN=448),
#  TestPower(p_column='test_60_256_640_p', t_column='test_60_256_640_time', iterations=60, trainingN=256, testingN=640),
#  TestPower(p_column='test_60_256_832_p', t_column='test_60_256_832_time', iterations=60, trainingN=256, testingN=832),
#  TestPower(p_column='test_60_448_64_p', t_column='test_60_448_64_time', iterations=60, trainingN=448, testingN=64),
#  TestPower(p_column='test_60_448_256_p', t_column='test_60_448_256_time', iterations=60, trainingN=448, testingN=256),
#  TestPower(p_column='test_60_448_448_p', t_column='test_60_448_448_time', iterations=60, trainingN=448, testingN=448),
#  TestPower(p_column='test_60_448_640_p', t_column='test_60_448_640_time', iterations=60, trainingN=448, testingN=640),
#  TestPower(p_column='test_60_448_832_p', t_column='test_60_448_832_time', iterations=60, trainingN=448, testingN=832),
#  TestPower(p_column='test_60_640_64_p', t_column='test_60_640_64_time', iterations=60, trainingN=640, testingN=64),
#  TestPower(p_column='test_60_640_256_p', t_column='test_60_640_256_time', iterations=60, trainingN=640, testingN=256),
#  TestPower(p_column='test_60_640_448_p', t_column='test_60_640_448_time', iterations=60, trainingN=640, testingN=448),
#  TestPower(p_column='test_60_640_640_p', t_column='test_60_640_640_time', iterations=60, trainingN=640, testingN=640),
#  TestPower(p_column='test_60_640_832_p', t_column='test_60_640_832_time', iterations=60, trainingN=640, testingN=832),
#  TestPower(p_column='test_60_832_64_p', t_column='test_60_832_64_time', iterations=60, trainingN=832, testingN=64),
#  TestPower(p_column='test_60_832_256_p', t_column='test_60_832_256_time', iterations=60, trainingN=832, testingN=256),
#  TestPower(p_column='test_60_832_448_p', t_column='test_60_832_448_time', iterations=60, trainingN=832, testingN=448),
#  TestPower(p_column='test_60_832_640_p', t_column='test_60_832_640_time', iterations=60, trainingN=832, testingN=640),
#  TestPower(p_column='test_60_832_832_p', t_column='test_60_832_832_time', iterations=60, trainingN=832, testingN=832),
#  TestPower(p_column='test_80_64_64_p', t_column='test_80_64_64_time', iterations=80, trainingN=64, testingN=64),
#  TestPower(p_column='test_80_64_256_p', t_column='test_80_64_256_time', iterations=80, trainingN=64, testingN=256),
#  TestPower(p_column='test_80_64_448_p', t_column='test_80_64_448_time', iterations=80, trainingN=64, testingN=448),
#  TestPower(p_column='test_80_64_640_p', t_column='test_80_64_640_time', iterations=80, trainingN=64, testingN=640),
#  TestPower(p_column='test_80_64_832_p', t_column='test_80_64_832_time', iterations=80, trainingN=64, testingN=832),
#  TestPower(p_column='test_80_256_64_p', t_column='test_80_256_64_time', iterations=80, trainingN=256, testingN=64),
#  TestPower(p_column='test_80_256_256_p', t_column='test_80_256_256_time', iterations=80, trainingN=256, testingN=256),
#  TestPower(p_column='test_80_256_448_p', t_column='test_80_256_448_time', iterations=80, trainingN=256, testingN=448),
#  TestPower(p_column='test_80_256_640_p', t_column='test_80_256_640_time', iterations=80, trainingN=256, testingN=640),
#  TestPower(p_column='test_80_256_832_p', t_column='test_80_256_832_time', iterations=80, trainingN=256, testingN=832),
#  TestPower(p_column='test_80_448_64_p', t_column='test_80_448_64_time', iterations=80, trainingN=448, testingN=64),
#  TestPower(p_column='test_80_448_256_p', t_column='test_80_448_256_time', iterations=80, trainingN=448, testingN=256),
#  TestPower(p_column='test_80_448_448_p', t_column='test_80_448_448_time', iterations=80, trainingN=448, testingN=448),
#  TestPower(p_column='test_80_448_640_p', t_column='test_80_448_640_time', iterations=80, trainingN=448, testingN=640),
#  TestPower(p_column='test_80_448_832_p', t_column='test_80_448_832_time', iterations=80, trainingN=448, testingN=832),
#  TestPower(p_column='test_80_640_64_p', t_column='test_80_640_64_time', iterations=80, trainingN=640, testingN=64),
#  TestPower(p_column='test_80_640_256_p', t_column='test_80_640_256_time', iterations=80, trainingN=640, testingN=256),
#  TestPower(p_column='test_80_640_448_p', t_column='test_80_640_448_time', iterations=80, trainingN=640, testingN=448),
#  TestPower(p_column='test_80_640_640_p', t_column='test_80_640_640_time', iterations=80, trainingN=640, testingN=640),
#  TestPower(p_column='test_80_640_832_p', t_column='test_80_640_832_time', iterations=80, trainingN=640, testingN=832),
#  TestPower(p_column='test_80_832_64_p', t_column='test_80_832_64_time', iterations=80, trainingN=832, testingN=64),
#  TestPower(p_column='test_80_832_256_p', t_column='test_80_832_256_time', iterations=80, trainingN=832, testingN=256),
#  TestPower(p_column='test_80_832_448_p', t_column='test_80_832_448_time', iterations=80, trainingN=832, testingN=448),
#  TestPower(p_column='test_80_832_640_p', t_column='test_80_832_640_time', iterations=80, trainingN=832, testingN=640),
#  TestPower(p_column='test_80_832_832_p', t_column='test_80_832_832_time', iterations=80, trainingN=832, testingN=832),
#  TestPower(p_column='test_100_64_64_p', t_column='test_100_64_64_time', iterations=100, trainingN=64, testingN=64),
#  TestPower(p_column='test_100_64_256_p', t_column='test_100_64_256_time', iterations=100, trainingN=64, testingN=256),
#  TestPower(p_column='test_100_64_448_p', t_column='test_100_64_448_time', iterations=100, trainingN=64, testingN=448),
#  TestPower(p_column='test_100_64_640_p', t_column='test_100_64_640_time', iterations=100, trainingN=64, testingN=640),
#  TestPower(p_column='test_100_64_832_p', t_column='test_100_64_832_time', iterations=100, trainingN=64, testingN=832),
#  TestPower(p_column='test_100_256_64_p', t_column='test_100_256_64_time', iterations=100, trainingN=256, testingN=64),
#  TestPower(p_column='test_100_256_256_p', t_column='test_100_256_256_time', iterations=100, trainingN=256, testingN=256),
#  TestPower(p_column='test_100_256_448_p', t_column='test_100_256_448_time', iterations=100, trainingN=256, testingN=448),
#  TestPower(p_column='test_100_256_640_p', t_column='test_100_256_640_time', iterations=100, trainingN=256, testingN=640),
#  TestPower(p_column='test_100_256_832_p', t_column='test_100_256_832_time', iterations=100, trainingN=256, testingN=832),
#  TestPower(p_column='test_100_448_64_p', t_column='test_100_448_64_time', iterations=100, trainingN=448, testingN=64),
#  TestPower(p_column='test_100_448_256_p', t_column='test_100_448_256_time', iterations=100, trainingN=448, testingN=256),
#  TestPower(p_column='test_100_448_448_p', t_column='test_100_448_448_time', iterations=100, trainingN=448, testingN=448),
#  TestPower(p_column='test_100_448_640_p', t_column='test_100_448_640_time', iterations=100, trainingN=448, testingN=640),
#  TestPower(p_column='test_100_448_832_p', t_column='test_100_448_832_time', iterations=100, trainingN=448, testingN=832),
#  TestPower(p_column='test_100_640_64_p', t_column='test_100_640_64_time', iterations=100, trainingN=640, testingN=64),
#  TestPower(p_column='test_100_640_256_p', t_column='test_100_640_256_time', iterations=100, trainingN=640, testingN=256),
#  TestPower(p_column='test_100_640_448_p', t_column='test_100_640_448_time', iterations=100, trainingN=640, testingN=448),
#  TestPower(p_column='test_100_640_640_p', t_column='test_100_640_640_time', iterations=100, trainingN=640, testingN=640),
#  TestPower(p_column='test_100_640_832_p', t_column='test_100_640_832_time', iterations=100, trainingN=640, testingN=832),
#  TestPower(p_column='test_100_832_64_p', t_column='test_100_832_64_time', iterations=100, trainingN=832, testingN=64),
#  TestPower(p_column='test_100_832_256_p', t_column='test_100_832_256_time', iterations=100, trainingN=832, testingN=256),
#  TestPower(p_column='test_100_832_448_p', t_column='test_100_832_448_time', iterations=100, trainingN=832, testingN=448),
#  TestPower(p_column='test_100_832_640_p', t_column='test_100_832_640_time', iterations=100, trainingN=832, testingN=640),
#  TestPower(p_column='test_100_832_832_p', t_column='test_100_832_832_time', iterations=100, trainingN=832, testingN=832))

# %% [markdown]
# # 3D box surface plot
#
# Given data on a gridded volume ``X``, ``Y``, ``Z``, this example plots the
# data values on the volume surfaces.
#
# The strategy is to select the data from each surface and plot
# contours separately using `.axes3d.Axes3D.contourf` with appropriate
# parameters *zdir* and *offset*.

# %%
# Define dimensions
iterations = frozenset(tp.iterations for tp in p_scores.keys())
trainingNs = frozenset(tp.trainingN for tp in p_scores.keys())
testingNs = frozenset(tp.testingN for tp in p_scores.keys())

X, Y, Z = np.meshgrid(sorted(iterations), sorted(trainingNs), sorted(testingNs))

data = None

p_data = np.array( [ [ [ p_scores.get(TestPower("", "", x, y, z), -10)
                         for x, y, z in zip(X_row, Y_row, Z_row) ]
                       for X_row, Y_row, Z_row in zip(X_frame, Y_frame, Z_frame) ]
                     for X_frame, Y_frame, Z_frame in zip(X, Y, Z) ]
                 )

t_data = np.array( [ [ [ high_times.get(TestPower("", "", x, y, z), -10)
                         for x, y, z in zip(X_row, Y_row, Z_row) ]
                       for X_row, Y_row, Z_row in zip(X_frame, Y_frame, Z_frame) ]
                     for X_frame, Y_frame, Z_frame in zip(X, Y, Z) ]
                 )
(p_data, t_data)
# Out:
# (array([[[385, 371, 365, 368, 355],
#          [380, 352, 351, 325, 334],
#          [374, 354, 331, 320, 307],
#          [370, 350, 312, 294, 290],
#          [367, 314, 304, 288, 270]],
#
#         [[333, 258, 203, 195, 163],
#          [292, 195, 158, 134, 118],
#          [237, 153, 119, 113,  93],
#          [244, 134, 107,  91,  77],
#          [219, 122, 100,  81,  74]],
#
#         [[299, 181, 134, 123,  89],
#          [219, 102,  77,  72,  58],
#          [187,  92,  62,  53,  37],
#          [156,  69,  51,  43,  36],
#          [131,  68,  40,  39,  29]],
#
#         [[251, 131,  89,  57,  69],
#          [175,  84,  51,  45,  32],
#          [134,  61,  46,  30,  30],
#          [114,  41,  27,  22,  19],
#          [ 95,  38,  22,  24,  18]],
#
#         [[215, 105,  56,  49,  36],
#          [144,  58,  37,  24,  23],
#          [103,  37,  29,  22,  19],
#          [ 89,  35,  22,  16,  16],
#          [ 77,  23,  13,  13,  12]]]),
#  array([[[ 1.49990796,  2.11630997,  2.73908584,  3.46397669,
#            4.11414354],
#          [ 1.93696602,  3.18269202,  4.48487928,  5.86872607,
#            7.19166792],
#          [ 2.38897197,  4.29180151,  6.25119309,  8.28915461,
#           10.28037052],
#          [ 2.84503433,  5.41024703,  8.04796793, 10.73808279,
#           13.39598791],
#          [ 3.30516884,  6.53712347,  9.81798019, 13.16706534,
#           16.48956035]],
#
#         [[ 2.18999901,  2.81473589,  3.53838086,  4.18832996,
#            4.83330425],
#          [ 3.34480449,  4.6404616 ,  6.02608822,  7.33380813,
#            8.6349891 ],
#          [ 4.53066362,  6.48588096,  8.52342176, 10.47992951,
#           12.45414229],
#          [ 5.72176471,  8.35074587, 11.0381417 , 13.65533754,
#           16.27730142],
#          [ 6.94222733, 10.21224438, 13.5512852 , 16.8325303 ,
#           20.11771693]],
#
#         [[ 2.92543638,  3.64996664,  4.29626457,  4.94274598,
#            5.59130688],
#          [ 4.83435202,  6.21256668,  7.52631372,  8.82189263,
#           10.13537291],
#          [ 6.75410574,  8.78847919, 10.75510836, 12.72148073,
#           14.68401462],
#          [ 8.69843815, 11.38223897, 14.01279955, 16.61455255,
#           19.24727613],
#          [10.64581285, 13.98504078, 17.28117775, 20.54363217,
#           23.81647998]],
#
#         [[ 3.7687903 ,  4.41745882,  5.06017414,  5.70821784,
#            6.36142668],
#          [ 6.41828868,  7.72612877,  9.0250853 , 10.33146948,
#           11.63182097],
#          [ 9.07907509, 11.04607768, 13.01125093, 14.9693968 ,
#           16.93401028],
#          [11.78296936, 14.40482275, 17.01306473, 19.64409711,
#           22.2565638 ],
#          [14.46153872, 17.74372987, 21.01073841, 24.28139325,
#           27.55520307]],
#
#         [[ 4.54202674,  5.18816888,  5.83362259,  6.48082621,
#            7.13763891],
#          [ 7.94042624,  9.24323057, 10.5512604 , 11.84702641,
#           13.15621153],
#          [11.3573644 , 13.32480106, 15.28613529, 17.24208527,
#           19.21463622],
#          [14.80905633, 17.41538952, 20.04072862, 22.65118171,
#           25.2753451 ],
#          [18.24122379, 21.50315871, 24.77241774, 28.04987087,
#           31.32141763]]]))

# %%
p_kw = {
    'vmin': min(p_scores.values()),
    'vmax': max(p_scores.values()),
    #'levels': np.linspace(min(results.values()), max(results.values()), 10),
    'levels': np.array([10, 15, 20, 30, 40, 50, 60, 75, 90, 115, 400]),
    'colors': ['white', '0.94', 'lightgrey', 'lightsteelblue', 'slateblue', 'blue', 'fuchsia', 'red', 'darkred', 'black']
}
t_kw = {
    'vmin': 0,
    'vmax': t_data.max(),
    'levels': np.linspace(0, t_data.max(), 10),
}

xmin, xmax = X.min(), X.max()
ymin, ymax = Y.min(), Y.max()
zmin, zmax = Z.min(), Z.max()

edges_kw = dict(color=(0.0, 1.0, 0.0, 0.15), linewidth=1, zorder=1e3)

axes_set_kw = {'xlim': [xmin, xmax], 'ylim': [ymin, ymax], 'zlim': [zmin, zmax],
               'xticks': list(iterations), 'yticks': list(trainingNs), 'zticks': list(testingNs),
               'xlabel':'iters', 'ylabel':'trainN', 'zlabel':'testN'}
def configure_ax(ax, foreground):
    if foreground:
        for i in iterations:
            ax.plot([i, i], [ymin, ymax], [zmin, zmin], **edges_kw)
            ax.plot([i, i], [ymin, ymin], [zmin, zmax], **edges_kw)
        for t in trainingNs:
            ax.plot([xmin, xmax], [t, t], [zmin, zmin], **edges_kw)
            ax.plot([xmin, xmin], [t, t], [zmin, zmax], **edges_kw)
        for t in testingNs:
            ax.plot([xmin, xmax], [ymin, ymin], [t, t], **edges_kw)
            ax.plot([xmin, xmin], [ymin, ymax], [t, t], **edges_kw)
    else:
        for i in iterations:
            ax.plot([i, i], [ymin, ymax], [zmax, zmax], **edges_kw)
            ax.plot([i, i], [ymax, ymax], [zmin, zmax], **edges_kw)
        for t in trainingNs:
            ax.plot([xmin, xmax], [t, t], [zmax, zmax], **edges_kw)
            ax.plot([xmax, xmax], [t, t], [zmin, zmax], **edges_kw)
        for t in testingNs:
            ax.plot([xmin, xmax], [ymax, ymax], [t, t], **edges_kw)
            ax.plot([xmax, xmax], [ymin, ymax], [t, t], **edges_kw)
        
    ax.set(**axes_set_kw)
    ax.view_init(40, 30, 0)
    #ax.set_box_aspect((xmax/xmin, ymax/ymin, zmax/zmin), zoom=0.9)

# %%
plt.tight_layout()

# Create a figure with 3D ax
fig1 = plt.figure(figsize=(4, 4))
ax1 = fig1.add_subplot(111, projection='3d')

# Plot contour surfaces
_ = ax1.contourf(
    X[:, :, 0], Y[:, :, 0], p_data[:, :, 0],
    zdir='z', offset=Z.min(), **p_kw
)
_ = ax1.contourf(
    X[0, :, :], p_data[0, :, :], Z[0, :, :],
    zdir='y', offset=Y.min(), **p_kw
)
_ = ax1.contourf(
    p_data[:, 0, :], Y[:, 0, :], Z[:, 0, :],
    zdir='x', offset=X.min(), **p_kw
)
# --
configure_ax(ax1, True)
fig1.savefig("../paper/graphs/cube_scores_back.pdf")
fig1.show()

fig2 = plt.figure(figsize=(4,4))
ax2 = fig2.add_subplot(111, projection='3d')

# Plot contour surfaces
_ = ax2.contourf(
    X[:, :, -1], Y[:, :, -1], p_data[:, :, -1],
    zdir='z', offset=Z.max(), **p_kw
)
_ = ax2.contourf(
    X[-1, :, :], p_data[-1, :, :], Z[-1, :, :],
    zdir='y', offset=Y.max(), **p_kw
)
C = ax2.contourf(
    p_data[:, -1, :], Y[:, -1, :], Z[:, -1, :],
    zdir='x', offset=X.max(), **p_kw
)
# --
configure_ax(ax2, False)

# Colorbar
fig2.colorbar(C, ax=ax2, fraction=0.02, pad=0.1, label='Total score',
             ticks=[0,1,2, 3,4, 5,6, 7,9,13,200])
fig2.savefig("../paper/graphs/cube_scores_front.pdf")
fig2.show()


fig3 = plt.figure(figsize=(4,4))
ax3 = fig3.add_subplot(111, projection='3d')

# Plot contour surfaces
_ = ax3.contourf(
    X[:, :, 0], Y[:, :, 0], t_data[:, :, 0],
    zdir='z', offset=Z.min(), **t_kw
)
_ = ax3.contourf(
    X[0, :, :], t_data[0, :, :], Z[0, :, :],
    zdir='y', offset=Y.min(), **t_kw
)
_ = ax3.contourf(
    t_data[:, 0, :], Y[:, 0, :], Z[:, 0, :],
    zdir='x', offset=X.min(), **t_kw
)
# --
configure_ax(ax3, True)
fig3.savefig("../paper/graphs/cube_times_back.pdf")
fig3.show()


fig4 = plt.figure(figsize=(4,4))
ax4 = fig4.add_subplot(111, projection='3d')

# Plot contour surfaces
_ = ax4.contourf(
    X[:, :, -1], Y[:, :, -1], t_data[:, :, -1],
    zdir='z', offset=Z.max(), **t_kw
)
_ = ax4.contourf(
    X[-1, :, :], t_data[-1, :, :], Z[-1, :, :],
    zdir='y', offset=Y.max(), **t_kw
)
D = ax4.contourf(
    t_data[:, -1, :], Y[:, -1, :], Z[:, -1, :],
    zdir='x', offset=X.max(), **t_kw
)
# --
configure_ax(ax4, False)

# Colorbar
fig4.colorbar(D, ax=ax4, fraction=0.02, pad=0.1, label='estimated high time')
fig4.savefig("../paper/graphs/cube_times_front.pdf")
fig4.show()

# Show Figure
#plt.show()
# Out:
# /tmp/ipykernel_42998/1725383061.py:23: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig1.show()
# /tmp/ipykernel_42998/1725383061.py:48: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig2.show()
# /tmp/ipykernel_42998/1725383061.py:70: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig3.show()
# /tmp/ipykernel_42998/1725383061.py:95: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig4.show()

# %% [markdown]
# Each p-value > 0.05 contributes 2 to the total score, and each > 0.01 contributes 1; lower scores are better.
#
# - Good results are impossible with sparse `training` data, regardless of other parameters.
# - The number of `iterations` of the experiment does seem to have trade-offs with other parameters, but good results are possible even with very few iterations.
# - Modest results are possible with sparse `testing` data, being of intermediate importance, but I'm struggling to be more specific...
